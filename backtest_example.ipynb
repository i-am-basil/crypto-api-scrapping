# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from backtest_instruments.strategies import calculate_bollinger_bands, bollinger_bands_strategy, plot_returns

# %%
ticker = 'PAXUSDT'
data = pd.read_csv(f'data/{ticker}.csv').drop('Unnamed: 0', axis=1)
data.head()
# Out:
#     timestamp    open    high     low   close
# 0  2018-12-12  1.0021  1.0054  0.9998  1.0019
# 1  2018-12-13  1.0019  1.0068  1.0005  1.0052
# 2  2018-12-14  1.0052  1.0118  1.0041  1.0071
# 3  2018-12-15  1.0071  1.0098  1.0045  1.0064
# 4  2018-12-16  1.0080  1.0094  1.0041  1.0068

# %%
# Apply the Bollinger Bands calculation
calculate_bollinger_bands(data)
# Apply the reversal trading strategy
bollinger_bands_strategy(data)
# Plot returns
plot_returns(data)

# %%
ticker = 'XMRUSDT'
data = pd.read_csv(f'data/{ticker}.csv').drop('Unnamed: 0', axis=1)
calculate_bollinger_bands(data)
bollinger_bands_strategy(data)
plot_returns(data)

# %%
ticker = 'BUSDUSDT'
data = pd.read_csv(f'data/{ticker}.csv').drop('Unnamed: 0', axis=1)
calculate_bollinger_bands(data)
bollinger_bands_strategy(data)
plot_returns(data)
